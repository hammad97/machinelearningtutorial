# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

df_train = pd.read_csv('train.csv')
df_store = pd.read_csv('store.csv')

#1.
print('Maximum sale recorded in : ')
maxSaleIndex = df_train['Sales'].idxmax()

print('Store id: ' , df_train.iloc[maxSaleIndex]['Store'] , ', Date: ' , df_train.iloc[maxSaleIndex]['Date']
      , ', Sales on the day: ' , df_train.iloc[maxSaleIndex]['Sales'])
# Out:
# Maximum sale recorded in :
# Store id:  909 , Date:  2015-06-22 , Sales on the day:  41551
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#2.
maxCompDistInd = df_store['CompetitionDistance'].idxmax()
minCompDistInd = df_store['CompetitionDistance'].idxmin()

print('Max Competition Distance by :')

print('Store id: ' , df_store.iloc[maxCompDistInd]['Store'] , ', Competition Distance: ' , df_store.iloc[maxCompDistInd]['CompetitionDistance'])

print('Least Competition Distance by :')    

print('Store id: ' , df_store.iloc[minCompDistInd]['Store'] , ', Competition Distance: ' , df_store.iloc[minCompDistInd]['CompetitionDistance'])
# Out:
# Max Competition Distance by :
# Store id:  453 , Competition Distance:  75860.0
# Least Competition Distance by :
# Store id:  516 , Competition Distance:  20.0

# %%
#3.

groupByStore = df_train.groupby(by = ['Store'])

# %%
#4.

groupByPromo = df_train.groupby(by = ['Promo'])
promoMean = groupByPromo.mean()
print(promoMean[['Sales']])
# Out:
#              Sales
# Promo
# 0      4406.050805
# 1      7991.152046

# %%
#5.
groupByOpen = df_train.groupby(by = ['Open'])
openMin = groupByOpen.agg({'Sales' : ['mean', 'min', 'max']})
print(openMin)
# Out:
#             Sales
#              mean min    max
# Open
# 0        0.000000   0      0
# 1     6955.514291   0  41551

# %%
#6.

df_merged = df_train.merge(df_store, how = "inner", on = "Store")
groupByType = df_merged.groupby(by = ["StoreType"])
salesSumByType = groupByType.sum()
print(salesSumByType[['Sales']])
# Out:
#                 Sales
# StoreType
# a          3165334859
# b           159231395
# c           783221426
# d          1765392943

# %% [markdown]
# Part B:

# %%
df_merged['Month'] = pd.DatetimeIndex(df_merged['Date']).month
groupByMonth = df_merged.groupby(by = ["Month"])
groupByMonth.mean()[['Sales']].plot.line()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df_merged['Day'] = pd.DatetimeIndex(df_merged['Date']).day
groupByDay = df_merged.groupby(by = ["Day"])
groupByDay.mean()[['Sales']].plot.line()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
df_merged['Year'] = pd.DatetimeIndex(df_merged['Date']).year
firstStoreId = df_merged['Store'].min()
firstYear = df_merged['Year'].min()

cSalesFF = df_merged.loc[(df_merged['Store'] == firstStoreId) 
                         & (df_merged['Year'] == firstYear), ["Sales", "Date"]]
cSalesFF.set_index('Date', inplace = True)
cSalesFF.sort_index().cumsum().plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
storeOpenData = df_train.loc[(df_train['Open'] == 1), ['Sales', 'Customers']]
customersData = storeOpenData.Customers.tolist()
salesData = storeOpenData.Sales.tolist()

plt.scatter(customersData, salesData)
plt.xlabel("Customers")
plt.ylabel("Sales")
plt.show()

# %%
cDistanceSalesData = df_merged.loc[(df_merged['Sales'] != 0) & 
                            (df_merged['CompetitionDistance']), ['Sales', 'CompetitionDistance']]
cDistanceData = cDistanceSalesData.CompetitionDistance.tolist()
sales2Data = cDistanceSalesData.Sales.tolist()
plt.scatter(cDistanceData, sales2Data)
plt.xlabel("CompetitionDistance")
plt.ylabel("Sales")
plt.show()

# %%
pearCorr = df_merged.corr()
pearCorr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_a0203_row0_col0,#T_a0203_row1_col1,#T_a0203_row2_col2,#T_a0203_row3_col3,#T_a0203_row4_col4,#T_a0203_row5_col5,#T_a0203_row6_col6,#T_a0203_row7_col7,#T_a0203_row8_col8,#T_a0203_row9_col9,#T_a0203_row10_col10,#T_a0203_row11_col11,#T_a0203_row12_col12,#T_a0203_row13_col13,#T_a0203_row14_col14{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_a0203_row0_col1,#T_a0203_row0_col4,#T_a0203_row7_col1,#T_a0203_row8_col1,#T_a0203_row8_col4,#T_a0203_row9_col1,#T_a0203_row10_col1,#T_a0203_row11_col1,#T_a0203_row11_col4,#T_a0203_row12_col1,#T_a0203_row12_col4,#T_a0203_row13_col4{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_a0203_row0_col2{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_a0203_row0_col3,#T_a0203_row8_col2{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_a0203_row0_col5,#T_a0203_row7_col5,#T_a0203_row8_col5,#T_a0203_row9_col5,#T_a0203_row10_col5,#T_a0203_row11_col5,#T_a0203_row12_col5{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_a0203_row0_col6,#T_a0203_row8_col6,#T_a0203_row9_col6,#T_a0203_row10_col3{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_a0203_row0_col7,#T_a0203_row0_col14,#T_a0203_row1_col14,#T_a0203_row7_col14,#T_a0203_row8_col14,#T_a0203_row9_col14,#T_a0203_row12_col8{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_a0203_row0_col8,#T_a0203_row7_col10{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_a0203_row0_col9,#T_a0203_row8_col7{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_a0203_row0_col10{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_a0203_row0_col11,#T_a0203_row7_col3,#T_a0203_row9_col12,#T_a0203_row14_col5{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_a0203_row0_col12,#T_a0203_row3_col6,#T_a0203_row3_col11{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_a0203_row0_col13,#T_a0203_row4_col13,#T_a0203_row8_col13,#T_a0203_row11_col8,#T_a0203_row12_col7{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_a0203_row1_col0,#T_a0203_row2_col1,#T_a0203_row4_col0,#T_a0203_row5_col0,#T_a0203_row6_col0,#T_a0203_row9_col0,#T_a0203_row10_col8,#T_a0203_row13_col0,#T_a0203_row14_col0{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_a0203_row1_col2,#T_a0203_row1_col3,#T_a0203_row1_col4,#T_a0203_row1_col5,#T_a0203_row1_col6,#T_a0203_row3_col10,#T_a0203_row4_col1,#T_a0203_row5_col14,#T_a0203_row7_col8,#T_a0203_row8_col0,#T_a0203_row9_col8,#T_a0203_row10_col7,#T_a0203_row10_col9,#T_a0203_row10_col13,#T_a0203_row11_col9,#T_a0203_row11_col12,#T_a0203_row11_col13,#T_a0203_row12_col11{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_a0203_row1_col7,#T_a0203_row4_col10,#T_a0203_row5_col7,#T_a0203_row6_col10,#T_a0203_row8_col10,#T_a0203_row14_col7{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_a0203_row1_col8,#T_a0203_row2_col0,#T_a0203_row2_col10,#T_a0203_row5_col8,#T_a0203_row6_col8,#T_a0203_row10_col0,#T_a0203_row11_col0,#T_a0203_row13_col8,#T_a0203_row14_col8{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_a0203_row1_col9,#T_a0203_row2_col13,#T_a0203_row3_col0,#T_a0203_row5_col9,#T_a0203_row14_col9{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_a0203_row1_col10,#T_a0203_row4_col7,#T_a0203_row5_col10,#T_a0203_row9_col11,#T_a0203_row14_col10{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_a0203_row1_col11,#T_a0203_row1_col12,#T_a0203_row4_col12,#T_a0203_row5_col11,#T_a0203_row5_col12,#T_a0203_row14_col6,#T_a0203_row14_col11,#T_a0203_row14_col12{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_a0203_row1_col13,#T_a0203_row7_col0{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_a0203_row2_col3{
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }#T_a0203_row2_col4{
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }#T_a0203_row2_col5{
#             background-color:  #3f93c2;
#             color:  #000000;
#         }#T_a0203_row2_col6,#T_a0203_row4_col6{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_a0203_row2_col7,#T_a0203_row7_col12,#T_a0203_row13_col10,#T_a0203_row13_col14{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_a0203_row2_col8,#T_a0203_row3_col7{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_a0203_row2_col9,#T_a0203_row2_col14,#T_a0203_row3_col9,#T_a0203_row5_col1,#T_a0203_row12_col0,#T_a0203_row12_col9{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_a0203_row2_col11{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_a0203_row2_col12{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_a0203_row3_col1,#T_a0203_row3_col14{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_a0203_row3_col2{
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }#T_a0203_row3_col4{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_a0203_row3_col5{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_a0203_row3_col8,#T_a0203_row7_col13,#T_a0203_row9_col13{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_a0203_row3_col12{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_a0203_row3_col13,#T_a0203_row9_col10{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_a0203_row4_col2{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_a0203_row4_col3{
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }#T_a0203_row4_col5{
#             background-color:  #76aad0;
#             color:  #000000;
#         }#T_a0203_row4_col8{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_a0203_row4_col9,#T_a0203_row6_col9,#T_a0203_row11_col7,#T_a0203_row13_col9{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_a0203_row4_col11,#T_a0203_row6_col11,#T_a0203_row6_col12{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_a0203_row4_col14,#T_a0203_row6_col13,#T_a0203_row6_col14,#T_a0203_row13_col7{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_a0203_row5_col2{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_a0203_row5_col3{
#             background-color:  #71a8ce;
#             color:  #000000;
#         }#T_a0203_row5_col4{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_a0203_row5_col6{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_a0203_row5_col13,#T_a0203_row8_col9,#T_a0203_row12_col13{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_a0203_row6_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_a0203_row6_col2{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_a0203_row6_col3,#T_a0203_row6_col5{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_a0203_row6_col4{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_a0203_row6_col7{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_a0203_row7_col2,#T_a0203_row12_col2{
#             background-color:  #bfc9e1;

# %%
firstTenStoresData = df_merged.loc[(df_merged['Store'] <= 10), ['Sales', 'Store']]
firstTenStoresData.boxplot(column = 'Sales', by = 'Store', figsize=(10,7))
plt.show()

# %% [markdown]
# Store 4 is having highest median sales.
